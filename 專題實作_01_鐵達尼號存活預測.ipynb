# %% [markdown]
# <a href="https://colab.research.google.com/github/ansal1202/titanic-analysis/blob/main/%E5%B0%88%E9%A1%8C%E5%AF%A6%E4%BD%9C_01_%E9%90%B5%E9%81%94%E5%B0%BC%E8%99%9F%E5%AD%98%E6%B4%BB%E9%A0%90%E6%B8%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder

#載入 Titanic 資料集
df = pd.read_csv('https://raw.githubusercontent.com/dsindy/kaggle-titanic/master/data/train.csv')
#移除缺失值
df = df.dropna()

# #選取數值欄位
df_encoded = df.select_dtypes(include=[np.number])

#計算相關係數矩陣
correlation_matrix = df_encoded.corr()

#顯示數值欄位與 "Survived" 欄位之間的相關係數 (按相關係數由大到小排序)
print(correlation_matrix['Survived'].sort_values(ascending=False))

#繪製相關係數矩陣熱圖
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix,annot=True,cmap='RdBu_r',linewidths=0.2)
fig=plt.gcf()
plt.title("Correlation Heatmap of Titanic")
plt.show()
# Out:
# Survived       1.000000
# PassengerId    0.148495
# Fare           0.134241
# SibSp          0.106346
# Parch          0.023582
# Pclass        -0.034542
# Age           -0.254085
# Name: Survived, dtype: float64
